# %%
import cv2
img=cv2.imread('iti.png')

# %%
from matplotlib import pyplot as plt

# %%
type(img)
# Out:
# numpy.ndarray

# %%
cv2.imshow('image',img)

# %%
import numpy as np

# %%
plt.imshow(img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
c=0
lab=np.zeros((265,265,3),np.uint8)
while 1:
    if c!=100:
        lab[:]=np.random.rand(1,3)*256
        cv2.imshow('lab',lab)
        cv2.waitKey(100)
        c=c+1
        out.write(lab)
        fourcc = cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
        writer = cv2.VideoWriter('project2.mp4', fourcc, 100, (265, 265))

    else:
        out.release()
        break
#out = cv2.VideoWriter(lab, 100, 20, (265, 265))

    # w, h = lab[0].size

# %%
import cv2
import numpy as np
import glob
 
img_array = []
for filename in glob.glob('/*.jpg'):
    img = cv2.imread(filename)
    height, width, layers = img.shape
    #size = (265,265)
    img_array.append(img)
 
 
out = cv2.VideoWriter('project.avi',cv2.VideoWriter_fourcc(*'DIVX'),15, (265,265))
 
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
